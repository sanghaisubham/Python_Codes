# %%
import pyautogui

# %%
pyautogui.displayMousePosition()
# Out:
# Press Ctrl-C to quit.
# X: 1028 Y:  401 RGB: (249, 249, 248)

# %%
pyautogui.screenshot()

# %%
pyautogui.screenshot('/home/TestScreenshot.png')
